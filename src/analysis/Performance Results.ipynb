# %%
import os
os.chdir("..")

# %%
import svm
import decision_tree
import random_forest
import gradient_boosting
import lg_boost
import xg_boost
import logistic_regression

import warnings
warnings.simplefilter("ignore", UserWarning)

if __name__=='__main__':
    performance_svm = svm.main()
    performance_dtree = decision_tree.main()
    performance_gradient = gradient_boosting.main()
    performance_random = random_forest.main()
    performance_lg = lg_boost.main()
    performance_xg = xg_boost.main()
    performance_lr = logistic_regression.main()
# Out:
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:333: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for group in _df.groupby(['structureNumber']):
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_scaled.rename(columns=temp_columns_hot_encoded, inplace=True)
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
#  Printing columns, one hot encoding:
# Using this function
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   positive_class['label'] = ['positive']*len(positive_class)
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negative_class['label'] = ['negative']*len(negative_class)
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:333: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for group in _df.groupby(['structureNumber']):
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_scaled.rename(columns=temp_columns_hot_encoded, inplace=True)
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
#  Printing columns, one hot encoding:
# Using this function
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   positive_class['label'] = ['positive']*len(positive_class)
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negative_class['label'] = ['negative']*len(negative_class)
# /Users/akale/miniconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:333: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for group in _df.groupby(['structureNumber']):
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_scaled.rename(columns=temp_columns_hot_encoded, inplace=True)
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
#  Printing columns, one hot encoding:
# Using this function
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   positive_class['label'] = ['positive']*len(positive_class)
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negative_class['label'] = ['negative']*len(negative_class)
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:333: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for group in _df.groupby(['structureNumber']):
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_scaled.rename(columns=temp_columns_hot_encoded, inplace=True)
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
#  Printing columns, one hot encoding:
# Using this function
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   positive_class['label'] = ['positive']*len(positive_class)
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negative_class['label'] = ['negative']*len(negative_class)
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:333: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for group in _df.groupby(['structureNumber']):
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_scaled.rename(columns=temp_columns_hot_encoded, inplace=True)
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
#  Printing columns, one hot encoding:
# Using this function
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   positive_class['label'] = ['positive']*len(positive_class)
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negative_class['label'] = ['negative']*len(negative_class)
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:333: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for group in _df.groupby(['structureNumber']):
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_scaled.rename(columns=temp_columns_hot_encoded, inplace=True)
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
#  Printing columns, one hot encoding:
# Using this function
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   positive_class['label'] = ['positive']*len(positive_class)
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negative_class['label'] = ['negative']*len(negative_class)
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:333: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for group in _df.groupby(['structureNumber']):
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_scaled.rename(columns=temp_columns_hot_encoded, inplace=True)
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
#  Printing columns, one hot encoding:
# Using this function
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   positive_class['label'] = ['positive']*len(positive_class)
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negative_class['label'] = ['negative']*len(negative_class)
# [20]	training's binary_logloss: 0.3306	valid_0's binary_logloss: 0.336172
# [40]	training's binary_logloss: 0.235897	valid_0's binary_logloss: 0.252202
# [60]	training's binary_logloss: 0.192875	valid_0's binary_logloss: 0.219851
# [80]	training's binary_logloss: 0.165017	valid_0's binary_logloss: 0.20276
# [100]	training's binary_logloss: 0.14547	valid_0's binary_logloss: 0.192098
# [20]	training's binary_logloss: 0.325525	valid_0's binary_logloss: 0.341346
# [40]	training's binary_logloss: 0.234081	valid_0's binary_logloss: 0.263554
# [60]	training's binary_logloss: 0.189493	valid_0's binary_logloss: 0.230517
# [80]	training's binary_logloss: 0.163462	valid_0's binary_logloss: 0.215309
# [100]	training's binary_logloss: 0.143113	valid_0's binary_logloss: 0.205075
# [20]	training's binary_logloss: 0.328495	valid_0's binary_logloss: 0.342614
# [40]	training's binary_logloss: 0.236468	valid_0's binary_logloss: 0.256327
# [60]	training's binary_logloss: 0.193959	valid_0's binary_logloss: 0.222255
# [80]	training's binary_logloss: 0.166254	valid_0's binary_logloss: 0.20305
# [100]	training's binary_logloss: 0.146718	valid_0's binary_logloss: 0.190963
# [20]	training's binary_logloss: 0.324102	valid_0's binary_logloss: 0.345941
# [40]	training's binary_logloss: 0.23599	valid_0's binary_logloss: 0.261763
# [60]	training's binary_logloss: 0.192675	valid_0's binary_logloss: 0.224656
# [80]	training's binary_logloss: 0.16659	valid_0's binary_logloss: 0.207204
# [100]	training's binary_logloss: 0.14675	valid_0's binary_logloss: 0.196729
# [20]	training's binary_logloss: 0.326539	valid_0's binary_logloss: 0.339634
# [40]	training's binary_logloss: 0.234698	valid_0's binary_logloss: 0.259268
# [60]	training's binary_logloss: 0.190567	valid_0's binary_logloss: 0.225373
# [80]	training's binary_logloss: 0.166076	valid_0's binary_logloss: 0.211336
# [100]	training's binary_logloss: 0.145145	valid_0's binary_logloss: 0.199247
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:333: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for group in _df.groupby(['structureNumber']):
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_scaled.rename(columns=temp_columns_hot_encoded, inplace=True)
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
#  Printing columns, one hot encoding:
# Using this function
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   positive_class['label'] = ['positive']*len(positive_class)
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negative_class['label'] = ['negative']*len(negative_class)
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:333: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for group in _df.groupby(['structureNumber']):
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_scaled.rename(columns=temp_columns_hot_encoded, inplace=True)
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df[key] = dict_col[key]
#  Printing columns, one hot encoding:
# Using this function
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   positive_class['label'] = ['positive']*len(positive_class)
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negative_class['label'] = ['negative']*len(negative_class)

# %%
# Access accuracy values using:
# Eg: performance_value (Accuracy) for SVM model can be accessed by:
performance_svm['accuracy']
# Out:
# [0.8056338028169014,
#  0.801056338028169,
#  0.8073943661971831,
#  0.8035211267605634,
#  0.8123239436619718]
