# %%
import os
os.chdir("..")

# %%
import svm
import decision_tree
import random_forest
import gradient_boosting
import lg_boost
import xg_boost
import logistic_regression

import warnings
warnings.simplefilter("ignore", UserWarning)

if __name__=='__main__':
    performance_svm = svm.main()
    performance_dtree = decision_tree.main()
    performance_gradient = gradient_boosting.main()
    performance_random = random_forest.main()
    performance_lg = lg_boost.main()
    performance_xg = xg_boost.main()
    performance_lr = logistic_regression.main()
# Out:
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:336: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for group in _df.groupby(['structureNumber']):
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_scaled.rename(columns=temp_columns_hot_encoded, inplace=True)
# /Users/akale/Documents/github/nbi-projects/ml-nbi/src/preprocessing.py:259: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# Access accuracy values using:
# Eg: performance_value (Accuracy) for SVM model can be accessed by:
print(performance_svm['accuracy'])
# Out:
# [0.8714788732394366, 0.8535211267605634, 0.877112676056338, 0.8845070422535212, 0.8718309859154929]
